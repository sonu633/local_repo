# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = np.random.randint(low=1 , high=100, size=(10,10))
print(data)
# Out:
# [[84 14 54 61 96 98 62 21 28 15]
#  [90 88 79 67 41 81 60 78 22 86]
#  [13 42 15 80 82  7 63 76 37 63]
#  [17 91 20 19 12 16 26 72 81 16]
#  [96 98 64  6 90  3 28 53 99 56]
#  [ 5 61 67 91 88 98 93 97 26 69]
#  [76 29 88 46 67 51 71 57 81 18]
#  [90 26 29  7 79 62 78 28 67 10]
#  [31  8 55 74 93 38 17 53 56 91]
#  [69 27 67 22 80 31 78 63 93 42]]

# %%
sns.heatmap(data=data)
# Out:
# <Axes: >

# %%
sns.heatmap(data=data, cmap="GnBu",alpha=0.5)
# Out:
# <Axes: >

# %%
sns.heatmap(data=data,linecolor="yellow",linewidth="2")
# Out:
# <Axes: >

# %%
sns.heatmap(data=data, annot= True)
# Out:
# <Axes: >

# %%
sns.heatmap(data=data, cbar=False)
# Out:
# <Axes: >

# %%
sns.heatmap(data=data, xticklabels =False, yticklabels =False)
# Out:
# <Axes: >
