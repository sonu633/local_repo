# %%
#(A part of Big Data Analysis)

#A Flights Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"c:\Users\DELL\Downloads\airlines_flights_data.csv")

# %%
# Remove the index column

data.drop(columns="index",inplace=True)

# %%
data
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
# Get started summary about the dataset

data.describe()
# Out:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751   20889.660523
# std         7.191997      13.561004   22697.767366
# min         0.830000       1.000000    1105.000000
# 25%         6.830000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max        49.830000      49.000000  123071.000000

# %%
data[data["duration"]==49.830000]
# Out:
#           airline  flight source_city departure_time        stops  \
# 193889  Air_India  AI-672     Chennai        Evening  two_or_more
# 194359  Air_India  AI-672     Chennai        Evening          one
#
#        arrival_time destination_city    class  duration  days_left  price
# 193889      Evening        Bangalore  Economy     49.83          2  23891
# 194359      Evening        Bangalore  Economy     49.83          9  17538

# %%
data[data["duration"]==0.830000]
# Out:
#        airline   flight source_city departure_time stops   arrival_time  \
# 115869  Indigo   6E-357   Bangalore          Night  zero          Night
# 115943  Indigo   6E-357   Bangalore          Night  zero          Night
# 116010  Indigo   6E-357   Bangalore          Night  zero          Night
# 116081  Indigo   6E-357   Bangalore          Night  zero          Night
# 116163  Indigo   6E-357   Bangalore          Night  zero          Night
# 116236  Indigo   6E-357   Bangalore          Night  zero          Night
# 116322  Indigo   6E-357   Bangalore          Night  zero          Night
# 116411  Indigo   6E-357   Bangalore          Night  zero          Night
# 116496  Indigo   6E-357   Bangalore          Night  zero          Night
# 116656  Indigo   6E-357   Bangalore          Night  zero          Night
# 116835  Indigo   6E-357   Bangalore          Night  zero          Night
# 116924  Indigo   6E-357   Bangalore          Night  zero          Night
# ...

# %%
data[data["price"]==17538]
# Out:
#           airline  flight source_city departure_time        stops  \
# 187601    Vistara  UK-836     Chennai        Morning          one
# 187602    Vistara  UK-836     Chennai        Morning          one
# 187603    Vistara  UK-836     Chennai        Morning          one
# 187604    Vistara  UK-834     Chennai        Evening          one
# 187605    Vistara  UK-834     Chennai        Evening          one
# 187700    Vistara  UK-832     Chennai  Early_Morning          one
# 188055    Vistara  UK-834     Chennai        Evening          one
# 188056    Vistara  UK-834     Chennai        Evening          one
# 188057    Vistara  UK-834     Chennai        Evening          one
# 194358  Air_India  AI-766     Chennai        Morning          one
# 194359  Air_India  AI-672     Chennai        Evening          one
# 197905    Vistara  UK-832     Chennai  Early_Morning  two_or_more
# 198286    Vistara  UK-834     Chennai        Evening          one
# ...

# %%
data.isnull().sum()                                          # check for the missing values in my column
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
Q.1 what are the airlines in the dataset,accompanied by their frequencies?
# Out:
# Object `frequencies` not found.

# %%
data.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
# checking how many  Airlines are in  the dataset

# %%
data["airline"].unique()
# Out:
# array(['SpiceJet', 'AirAsia', 'Vistara', 'GO_FIRST', 'Indigo',
#        'Air_India'], dtype=object)

# %%
data["airline"].nunique()
# Out:
# 6

# %%
# showing all the Airlines with their frequency
data["airline"].value_counts()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %%
# Showing all the Airlines with their number of flights in Bar graph
data["airline"].value_counts(ascending =True).plot.barh(color=["lightblue","lightgreen"])                                                                                                            "])# for horizontel graph using barh function

plt.show()
# Out:
#   Cell In[361], line 2
#     data["airline"].value_counts(ascending =True).plot.barh(color=["lightblue","lightgreen"])                                                                                                            "])# for horizontel graph using barh function
#                                                                                                                                                                                                          ^
# SyntaxError: unterminated string literal (detected at line 2)
